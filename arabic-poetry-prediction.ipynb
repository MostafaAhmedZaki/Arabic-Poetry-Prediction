# %% [markdown]
# ## Machathon 2.0 Qualification Round
# ### Arabic Poetry Meter

# %%
import os
import io
import glob
import numpy as np
import pandas as pd
import tensorflow as tf
from random import shuffle
from pyarabic import araby
from sklearn.utils import shuffle
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import GRU, Embedding, Dense, Input, Dropout, Bidirectional
# !pip install pyarabic
# Out:
# Requirement already satisfied: pyarabic in /opt/conda/lib/python3.7/site-packages (0.6.10)

# %% [markdown]
# ### Reading Data

# %%
df=pd.read_csv('../input/poemdatasett/train.csv',header=0)
df=pd.read_csv(io.StringIO(u""+df.to_csv(header=None,index=False)), header=None)
df.to_csv("trainFile.txt", header=None, index=None, sep=' ', mode='w')

# %%
with open('../input/poemdatasett/labels.txt', 'r') as f:
    data_labels = f.readlines()
    data_labels = [name.replace('\n', '') for name in data_labels]

# %% [markdown]
# ### Preprocessing Arabic Data

# %%
def splitting(path, thresh = 70, on_shatrs = False):
    
    global ALL_WORDS
    words = ""
    X = []
    y = []
    file = open(path, 'r').read()
    file = araby.strip_tashkeel(file)
    removed = '!()*-ـ.:=o[]«»;؛,،~?؟\u200f\ufeffـ'
    after_R = ""
    for char in file:
        if char not in removed:
            after_R += char
    words += after_R
    splitted = after_R.split('\n')
    for line in splitted:
        if len(line) <= 1:
            continue
        data_label, splitted = line.split(' ', 1)
        data_label = int(data_label)
        splitted  = splitted.strip()
        if on_shatrs:
            shatrs = splitted.split('#')
            for shatr in shatrs:
                X.append(shatr.strip())
                y.append(data_label)
        else:
            X.append(splitted.strip())
            y.append(data_label)
    ALL_WORDS = sorted(set(' '.join(X)))  
    X, y = shuffle(X, y)
        
    return X, y

# %%
X, y = splitting("./trainFile.txt", on_shatrs=False)

# %% [markdown]
# ### Showing First Five Abyat

# %%
for i in range(5):
    print(X[i], ' ', data_labels[y[i]])
# Out:
# "اذا هبط القوم المباغي سمت به # مآرب شتى ما يسف رفيعها"   mutakareb
# "وانتقال الطبع شيء معوز # مثل ما أعوز لين الجلمد"   ramal
# "وللهجاء نجوم # ترى سماءك أرضا"   mujtath
# "مبتدا الحسن صيغ منها ومنها # فرق الحسن في جميع العباد"   khafeef
# "لا توحش الوحدة أصحابها # إن سهيلا وحده فارد"   saree

# %% [markdown]
# ### Splitting to train & validation data

# %%
X_train, X_validation , y_train, y_validation = train_test_split(X, y, test_size = 0.18, random_state = 30)

# %% [markdown]
# ### Converting Arabic Characters to Index

# %%
convert_char_idx = {u:i+1 for i, u in enumerate(ALL_WORDS)}

# %% [markdown]
# ### Making Sequences

# %%
def padding(X):
    X = [[convert_char_idx[char] for char in line] for line in X]
    X = pad_sequences(X, padding='post', value=0, maxlen = 100)
    return X

# %%
X_train = padding(X_train)
X_validation = padding(X_validation)
y_train = np.array(y_train)
y_validation = np.array(y_validation)

# %% [markdown]
# ### Building The Model

# %%
classifier = Sequential()
classifier.add(Input((100,)))
classifier.add(Embedding(len(convert_char_idx)+1, 256))
classifier.add(Bidirectional(GRU(units = 512, return_sequences=True)))
classifier.add(Bidirectional(GRU(units = 256, return_sequences=True)))
classifier.add(Bidirectional(GRU(units = 256, return_sequences=True)))
classifier.add(Bidirectional(GRU(units = 256)))
classifier.add(Dense(64, activation = 'relu'))
classifier.add(Dropout(0.3))
classifier.add(Dense(len(data_labels), activation = 'softmax'))
classifier.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 256)          10240
# _________________________________________________________________
# bidirectional (Bidirectional (None, 100, 1024)         2365440
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 100, 512)          1969152
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 100, 512)          1182720
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 512)               1182720
# _________________________________________________________________
# dense (Dense)                (None, 64)                32832
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 14)                910
# =================================================================
# Total params: 6,744,014
# Trainable params: 6,744,014
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier(tf.zeros((10, 100))).shape
# Out:
# TensorShape([10, 14])

# %%
CB = [tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, min_delta=0.0001, min_lr=0.0001)]
CB += [tf.keras.callbacks.ModelCheckpoint('MAAN_Model', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')]

# %% [markdown]
# ### Training The Model

# %%
classifier.fit(X_train, y_train, validation_data= (X_validation, y_validation), epochs = 17, batch_size= 64, shuffle = True, callbacks=CB)
# Out:
# Epoch 1/17
# 257/257 [==============================] - 43s 134ms/step - loss: 2.5161 - accuracy: 0.1011 - val_loss: 2.3245 - val_accuracy: 0.1828
#
# Epoch 00001: val_accuracy improved from -inf to 0.18278, saving model to MAAN_Model
# Epoch 2/17
# 257/257 [==============================] - 32s 125ms/step - loss: 2.2668 - accuracy: 0.1829 - val_loss: 1.9493 - val_accuracy: 0.3419
#
# Epoch 00002: val_accuracy improved from 0.18278 to 0.34194, saving model to MAAN_Model
# Epoch 3/17
# 257/257 [==============================] - 32s 126ms/step - loss: 1.7420 - accuracy: 0.4279 - val_loss: 1.2366 - val_accuracy: 0.6050
#
# Epoch 00003: val_accuracy improved from 0.34194 to 0.60500, saving model to MAAN_Model
# Epoch 4/17
# 257/257 [==============================] - 32s 124ms/step - loss: 1.1537 - accuracy: 0.6441 - val_loss: 0.7966 - val_accuracy: 0.7494
#
# Epoch 00004: val_accuracy improved from 0.60500 to 0.74944, saving model to MAAN_Model
# Epoch 5/17
# 257/257 [==============================] - 32s 126ms/step - loss: 0.7826 - accuracy: 0.7677 - val_loss: 0.6263 - val_accuracy: 0.8056
#
# Epoch 00005: val_accuracy improved from 0.74944 to 0.80556, saving model to MAAN_Model
# Epoch 6/17
# 257/257 [==============================] - 32s 125ms/step - loss: 0.5816 - accuracy: 0.8276 - val_loss: 0.4926 - val_accuracy: 0.8428
#
# Epoch 00006: val_accuracy improved from 0.80556 to 0.84278, saving model to MAAN_Model
# Epoch 7/17
# 257/257 [==============================] - 32s 125ms/step - loss: 0.4324 - accuracy: 0.8740 - val_loss: 0.4776 - val_accuracy: 0.8569
#
# Epoch 00007: val_accuracy improved from 0.84278 to 0.85694, saving model to MAAN_Model
# Epoch 8/17
# 257/257 [==============================] - 32s 125ms/step - loss: 0.3915 - accuracy: 0.8873 - val_loss: 0.4272 - val_accuracy: 0.8733
#
# Epoch 00008: val_accuracy improved from 0.85694 to 0.87333, saving model to MAAN_Model
# Epoch 9/17
# 257/257 [==============================] - 33s 127ms/step - loss: 0.3098 - accuracy: 0.9135 - val_loss: 0.4001 - val_accuracy: 0.8853
#
# Epoch 00009: val_accuracy improved from 0.87333 to 0.88528, saving model to MAAN_Model
# Epoch 10/17
# 257/257 [==============================] - 32s 126ms/step - loss: 0.2596 - accuracy: 0.9287 - val_loss: 0.3816 - val_accuracy: 0.8919
#
# Epoch 00010: val_accuracy improved from 0.88528 to 0.89194, saving model to MAAN_Model
# Epoch 11/17
# 257/257 [==============================] - 33s 127ms/step - loss: 0.1958 - accuracy: 0.9465 - val_loss: 0.3995 - val_accuracy: 0.8956
#
# Epoch 00011: val_accuracy improved from 0.89194 to 0.89556, saving model to MAAN_Model
# Epoch 12/17
# 257/257 [==============================] - 32s 125ms/step - loss: 0.1680 - accuracy: 0.9518 - val_loss: 0.4025 - val_accuracy: 0.8889
#
# Epoch 00012: val_accuracy did not improve from 0.89556
# Epoch 13/17
# 257/257 [==============================] - 32s 126ms/step - loss: 0.1006 - accuracy: 0.9725 - val_loss: 0.3489 - val_accuracy: 0.9089
#
# Epoch 00013: val_accuracy improved from 0.89556 to 0.90889, saving model to MAAN_Model
# Epoch 14/17
# 257/257 [==============================] - 32s 124ms/step - loss: 0.0546 - accuracy: 0.9852 - val_loss: 0.3637 - val_accuracy: 0.9103
#
# Epoch 00014: val_accuracy improved from 0.90889 to 0.91028, saving model to MAAN_Model
# Epoch 15/17
# 257/257 [==============================] - 32s 125ms/step - loss: 0.0383 - accuracy: 0.9908 - val_loss: 0.3766 - val_accuracy: 0.9117
#
# Epoch 00015: val_accuracy improved from 0.91028 to 0.91167, saving model to MAAN_Model
# Epoch 16/17
# 257/257 [==============================] - 32s 124ms/step - loss: 0.0262 - accuracy: 0.9935 - val_loss: 0.3872 - val_accuracy: 0.9125
#
# Epoch 00016: val_accuracy improved from 0.91167 to 0.91250, saving model to MAAN_Model
# Epoch 17/17
# 257/257 [==============================] - 32s 125ms/step - loss: 0.0228 - accuracy: 0.9948 - val_loss: 0.3988 - val_accuracy: 0.9136
#
# Epoch 00017: val_accuracy improved from 0.91250 to 0.91361, saving model to MAAN_Model

# %% [markdown]
# ### Saving The Model

# %%
classifier.save('MAAN_Model_Final.h5')

# %% [markdown]
# ### Loading Model

# %%
classifier = tf.keras.models.load_model('MAAN_Model_Final.h5')

# %% [markdown]
# ### Classifier's Preprocessing Function

# %%
def classifier_preprocess_data(text, thresh = 70, on_shatrs = False):
    
    words = ""
    X = []
    text = araby.strip_tashkeel(text)
    removed = 'ـ!()*-ـ.:=o[]«»;؛,،~?؟\u200f\ufeffـ'
    after_R = ""
    for char in text:
        if char not in removed:
            after_R += char
    words += after_R
    splitted = after_R
    splitted  = splitted.strip()
    if on_shatrs:
        shatrs = splitted.split('#')
        for shatr in shatrs:
            X.append(shatr.strip())
    else:
        X.append(splitted.strip())
    X = X[0]
    return X

# %%
data_labels = {i:name for i, name in enumerate(data_labels)}

# %% [markdown]
# ### Prediction Function

# %%
def main_classify_func(sentence):
    sentence = classifier_preprocess_data(sentence, on_shatrs=False)
    sequence = [convert_char_idx[char] for char in sentence]
    sequence = pad_sequences([sequence], maxlen = X_train.shape[1], padding='post', value=0)
    pred = classifier.predict(sequence)[0]
    print(data_labels[np.argmax(pred, 0).astype('int')], np.max(pred))
    pred = np.argmax(pred, 0).astype('int')
    return pred

# %% [markdown]
# ### Reading and Classifying Test Data

# %%
test_data_df=pd.read_csv('../input/finaltestdata/test (2).csv')
main_classify_func(test_data_df.data[0])
# Out:
# baseet 0.99600405
# 8

# %%
test_data_dictionary = { i: main_classify_func(test_data_df.data[i]) for i in range(test_data_df.shape[0])}
list(test_data_dictionary.keys())[0]
# Out:
# baseet 0.99600405
# mutakareb 0.9970693
# mutakareb 0.9817545
# taweel 0.9956863
# wafer 0.98380107
# kamel 0.994706
# saree 0.8387061
# saree 0.9994566
# madeed 0.7971848
# khafeef 0.9997937
# saree 0.99575776
# kamel 0.93433625
# saree 0.9965758
# munsareh 0.9897233
# mujtath 0.99999654
# saree 0.9213738
# saree 0.6055784
# kamel 0.53376234
# khafeef 0.7701035
# saree 0.9938929
# kamel 0.79809475
# saree 0.4680685
# saree 0.6139803
# wafer 0.9309135
# ramal 0.999918
# khafeef 0.9999877
# saree 0.9868356
# baseet 0.83856905
# saree 0.58719015
# saree 0.99949217
# kamel 0.967025
# mutadarak 0.5601708
# mutakareb 0.99957377
# rajaz 0.9241643
# ramal 0.99997294
# ramal 0.98809487
# rajaz 0.732059
# munsareh 0.9997434
# khafeef 0.863121
# saree 0.99003875
# wafer 0.9994646
# mutakareb 0.92215896
# munsareh 0.9965994
# khafeef 0.5245455
# baseet 0.558357
# kamel 0.99857295
# rajaz 0.9303459
# munsareh 0.83004344
# kamel 0.99332726
# wafer 0.86682224
# khafeef 0.87944204
# ramal 0.95822936
# taweel 0.9896988
# baseet 0.7793427
# munsareh 0.9998994
# mutakareb 0.99791414
# kamel 0.6457696
# wafer 0.9991978
# mutakareb 0.41150588
# taweel 0.9820426
# saree 0.999129
# kamel 0.99885356
# taweel 0.9746002
# ramal 0.9348771
# wafer 0.9970182
# baseet 0.9959888
# munsareh 0.9789403
# wafer 0.70795053
# ramal 0.7800561
# mujtath 0.99962044
# mujtath 0.99982613
# khafeef 0.5757238
# wafer 0.994689
# mutakareb 0.9490461
# munsareh 0.9982168
# mutakareb 0.99117833
# khafeef 0.99939
# khafeef 0.99998736
# taweel 0.7949101
# khafeef 0.2881666
# rajaz 0.4648123
# kamel 0.7645793
# baseet 0.99917954
# munsareh 0.99995255
# baseet 0.9812765
# rajaz 0.9985885
# baseet 0.43450075
# saree 0.61287344
# saree 0.56410736
# kamel 0.998541
# ramal 0.9975478
# kamel 0.96861917
# saree 0.99874324
# wafer 0.9422509
# khafeef 0.9992654
# munsareh 0.98200226
# munsareh 0.98480195
# baseet 0.544325
# saree 0.50226444
# khafeef 0.9965127
# saree 0.50659716
# taweel 0.997928
# baseet 0.9981679
# wafer 0.49624512
# taweel 0.6596481
# khafeef 0.99863774
# rajaz 0.99972945
# khafeef 0.99992573
# mutakareb 0.99973625
# khafeef 0.9999927
# kamel 0.9998636
# wafer 0.98411906
# ramal 0.99633384
# taweel 0.9908574
# kamel 0.9999651
# wafer 0.9832364
# khafeef 0.9993686
# munsareh 0.9996443
# khafeef 0.9872363
# ramal 0.46562546
# mutakareb 0.99962306
# baseet 0.9975314
# khafeef 0.99924797
# mutakareb 0.9478188
# wafer 0.8703434
# baseet 0.99887747
# khafeef 0.5911581
# rajaz 0.4394173
# taweel 0.9581084
# saree 0.73759913
# khafeef 0.9985089
# wafer 0.86646086
# rajaz 0.9997198
# ramal 0.94733727
# mutakareb 0.896038
# mutakareb 0.99794227
# wafer 0.76015
# wafer 0.46802732
# khafeef 0.99999046
# baseet 0.9990263
# ramal 0.4223252
# mujtath 0.7572663
# rajaz 0.99993134
# wafer 0.92080784
# rajaz 0.99940276
# mutakareb 0.98721606
# ramal 0.94646007
# ramal 0.9999708
# mutakareb 0.8992834
# mutakareb 0.9989913
# baseet 0.99668735
# ramal 0.9999913
# khafeef 0.9999951
# taweel 0.9833182
# saree 0.99143136
# saree 0.99879944
# mutakareb 0.9998605
# kamel 0.99979836
# saree 0.99238753
# kamel 0.9432598
# khafeef 0.999987
# baseet 0.93952644
# ramal 0.52069175
# kamel 0.8124838
# taweel 0.9993783
# kamel 0.8915727
# kamel 0.9681666
# munsareh 0.99413115
# mutakareb 0.864248
# rajaz 0.5028628
# madeed 0.70854557
# mujtath 0.45421726
# saree 0.9975648
# khafeef 0.50094634
# baseet 0.6682801
# saree 0.7579821
# rajaz 0.99984753
# taweel 0.9971752
# khafeef 0.999275
# saree 0.98676145
# ramal 0.9999964
# mutakareb 0.9670118
# rajaz 0.9986243
# mutakareb 0.997366
# kamel 0.9815777
# mutakareb 0.9950747
# rajaz 0.9914287
# saree 0.9897816
# ramal 0.9027813
# ramal 0.99999094
# khafeef 0.9999883
# khafeef 0.99999607
# taweel 0.8347517
# taweel 0.86935407
# ramal 0.9993374
# wafer 0.8044681
# wafer 0.9237347
# ramal 0.99863976
# taweel 0.8705805
# khafeef 0.94960207
# taweel 0.9980191
# baseet 0.99966955
# ramal 0.9999858
# kamel 0.962891
# rajaz 0.721942
# khafeef 0.9999347
# ramal 0.9997311
# mujtath 0.6371319
# mutakareb 0.97062385
# mutakareb 0.9983033
# saree 0.5603658
# khafeef 0.99156356
# rajaz 0.5029664
# wafer 0.9699018
# saree 0.99335164
# ramal 0.99727863
# ramal 0.99999726
# wafer 0.89888436
# rajaz 0.42153606
# mutakareb 0.99511504
# saree 0.9678515
# munsareh 0.65768623
# baseet 0.9964868
# saree 0.99346596
# rajaz 0.9984617
# mutakareb 0.9524648
# munsareh 0.81890965
# rajaz 0.8217437
# ramal 0.9999939
# baseet 0.9988483
# saree 0.3043264
# rajaz 0.9021261
# ramal 0.9990024
# khafeef 0.40050772
# khafeef 0.9667505
# kamel 0.9985239
# saree 0.98867106
# saree 0.99874985
# kamel 0.9995153
# saree 0.7018969
# baseet 0.9990926
# saree 0.9255826
# rajaz 0.9567751
# munsareh 0.9105281
# khafeef 0.9999021
# saree 0.98272485
# baseet 0.96394664
# khafeef 0.9999888
# wafer 0.9919499
# kamel 0.82833046
# taweel 0.9996537
# khafeef 0.99998474
# taweel 0.99913955
# taweel 0.9727117
# mutakareb 0.70680326
# ramal 0.99897134
# kamel 0.9980488
# kamel 0.9116999
# taweel 0.9871021
# wafer 0.9204084
# munsareh 0.99886864
# saree 0.3629602
# ramal 0.99961275
# taweel 0.9997013
# saree 0.3963163
# khafeef 0.5695092
# wafer 0.6653664
# saree 0.9968958
# kamel 0.97329944
# saree 0.99970835
# taweel 0.9998361
# kamel 0.99930334
# khafeef 0.71902525
# rajaz 0.9171128
# rajaz 0.9689229
# saree 0.8929128
# wafer 0.33900964
# taweel 0.9849449
# saree 0.9791638
# ramal 0.99985266
# munsareh 0.99987936
# kamel 0.9951072
# ramal 0.91722333
# saree 0.9990023
# ramal 0.9996836
# rajaz 0.9870135
# kamel 0.9996952
# kamel 0.9984939
# khafeef 0.99981064
# saree 0.99954885
# mutakareb 0.57175446
# rajaz 0.6176886
# rajaz 0.74745655
# baseet 0.80261904
# ramal 0.9999505
# rajaz 0.9998456
# ramal 0.9995136
# khafeef 0.99887305
# wafer 0.9327896
# taweel 0.91271883
# rajaz 0.7653693
# taweel 0.99783117
# saree 0.64732665
# mutakareb 0.94866455
# mutakareb 0.99679583
# rajaz 0.98677164
# mutakareb 0.96552604
# munsareh 0.92979896
# baseet 0.9158393
# saree 0.4935482
# rajaz 0.9999441
# ramal 0.99989915
# baseet 0.99690646
# mutakareb 0.9999021
# mutakareb 0.877805
# rajaz 0.81289315
# wafer 0.991581
# taweel 0.96858335
# kamel 0.72104406
# baseet 0.99908924
# taweel 0.9982192
# baseet 0.9605157
# mutakareb 0.99744594
# saree 0.9978132
# ramal 0.99854445
# saree 0.542318
# rajaz 0.9602639
# khafeef 0.67863196
# saree 0.92911154
# baseet 0.97777987
# ramal 0.98953843
# rajaz 0.5064492
# ramal 0.99999475
# baseet 0.9876565
# khafeef 0.9999329
# rajaz 0.9999404
# ramal 0.9878962
# khafeef 0.99998283
# wafer 0.7811469
# wafer 0.9907355
# baseet 0.998135
# baseet 0.97793216
# wafer 0.7908521
# saree 0.99731207
# rajaz 0.9955047
# wafer 0.71030605
# khafeef 0.90398604
# saree 0.9971957
# saree 0.943267
# saree 0.71609294
# rajaz 0.42895043
# mutakareb 0.6011493
# taweel 0.9958902
# wafer 0.9574444
# khafeef 0.8291205
# khafeef 0.99793565
# mutakareb 0.9997894
# khafeef 0.9316932
# baseet 0.99245876
# rajaz 0.39611983
# baseet 0.80878335
# baseet 0.9959603
# ramal 0.9700154
# mutakareb 0.7405345
# taweel 0.98053074
# khafeef 0.99999833
# mutakareb 0.65519786
# kamel 0.96896523
# rajaz 0.99978083
# baseet 0.99880636
# ramal 0.99999785
# rajaz 0.9916099
# saree 0.99564016
# munsareh 0.999569
# rajaz 0.6835707
# wafer 0.96792644
# mutakareb 0.5999219
# khafeef 0.537757
# baseet 0.99867815
# mujtath 0.9933582
# mujtath 0.9992555
# rajaz 0.9566388
# taweel 0.9965166
# taweel 0.8250057
# taweel 0.9806687
# saree 0.63950545
# saree 0.3897578
# mutakareb 0.697285
# ramal 0.7070058
# munsareh 0.99863607
# baseet 0.99703777
# ramal 0.9898846
# ramal 0.768092
# rajaz 0.9995639
# khafeef 0.9999348
# kamel 0.75255626
# kamel 0.9979533
# rajaz 0.99859196
# kamel 0.60757136
# munsareh 0.4213333
# saree 0.64762396
# mutakareb 0.50303924
# rajaz 0.59383297
# khafeef 0.8504232
# mutakareb 0.61939865
# ramal 0.97917557
# saree 0.9972608
# saree 0.9988513
# mutakareb 0.8753283
# mutakareb 0.98987246
# saree 0.99949217
# mutakareb 0.99988544
# taweel 0.7256884
# khafeef 0.9616958
# rajaz 0.99998534
# kamel 0.56452507
# wafer 0.98965645
# khafeef 0.9999461
# taweel 0.9622449
# wafer 0.52576786
# rajaz 0.63561827
# khafeef 0.99192905
# khafeef 0.99990654
# kamel 0.9998591
# munsareh 0.97629535
# mutakareb 0.30714342
# ramal 0.7900096
# rajaz 0.999579
# baseet 0.99844486
# saree 0.3105593
# mutakareb 0.99596584
# baseet 0.96511805
# wafer 0.915271
# mujtath 0.9993957
# khafeef 0.9999981
# wafer 0.940134
# khafeef 0.99976283
# saree 0.99974877
# wafer 0.9924233
# hazaj 0.9424092
# ramal 0.73087645
# rajaz 0.5755234
# munsareh 0.8568325
# kamel 0.93629867
# saree 0.99798846
# mutakareb 0.9626319
# saree 0.9993174
# mutakareb 0.9996791
# baseet 0.993877
# baseet 0.9816321
# ramal 0.99943465
# ramal 0.9998977
# munsareh 0.9989159
# wafer 0.84053487
# khafeef 0.99999475
# mutakareb 0.9792849
# taweel 0.99513286
# rajaz 0.9986355
# wafer 0.97423416
# mutakareb 0.50772244
# madeed 0.77423716
# mutakareb 0.93422145
# ramal 0.9355121
# munsareh 0.9626165
# wafer 0.98991126
# taweel 0.9891992
# munsareh 0.8714935
# kamel 0.8630109
# khafeef 0.9984847
# ramal 0.7031851
# mutakareb 0.99827635
# rajaz 0.9999683
# mutakareb 0.5358908
# baseet 0.99435306
# ramal 0.9999865
# baseet 0.9998503
# wafer 0.97280663
# taweel 0.9703087
# taweel 0.99959844
# khafeef 0.9992974
# rajaz 0.9983198
# khafeef 0.98685455
# saree 0.9539521
# saree 0.99923396
# wafer 0.9663998
# khafeef 0.9229454
# baseet 0.99516773
# munsareh 0.99422693
# rajaz 0.99982446
# khafeef 0.99745864
# taweel 0.96382713
# ramal 0.9962598
# khafeef 0.99984396
# khafeef 0.9960729
# khafeef 0.6363321
# saree 0.39729315
# kamel 0.9949325
# taweel 0.5852965
# wafer 0.9656991
# rajaz 0.8638307
# baseet 0.9969758
# ramal 0.70415294
# ramal 0.95866245
# saree 0.71242446
# taweel 0.99981695
# baseet 0.9961422
# kamel 0.83669627
# taweel 0.99965346
# saree 0.8015294
# saree 0.45402694
# mutakareb 0.9245636
# mutakareb 0.999897
# baseet 0.8887801
# khafeef 0.99931693
# ramal 0.84402627
# taweel 0.9902586
# saree 0.5670485
# taweel 0.98783803
# madeed 0.8026615
# baseet 0.994091
# mujtath 0.9978721
# munsareh 0.9496587
# khafeef 0.9999815
# rajaz 0.68829
# kamel 0.9993668
# rajaz 0.9999943
# taweel 0.98596835
# ramal 0.9999572
# munsareh 0.996198
# saree 0.9941572
# kamel 0.54932696
# munsareh 0.67168826
# rajaz 0.99914515
# kamel 0.9927568
# baseet 0.9805046
# munsareh 0.7766898
# khafeef 0.79808
# rajaz 0.78162724
# madeed 0.77893484
# saree 0.997282
# kamel 0.9966858
# khafeef 0.88973033
# ramal 0.85746425
# khafeef 0.9999405
# mutakareb 0.91980207
# kamel 0.99726933
# munsareh 0.99996686
# ramal 0.99997556
# kamel 0.99979264
# saree 0.99764246
# rajaz 0.55701464
# kamel 0.98672116
# mutakareb 0.99795306
# munsareh 0.9970054
# baseet 0.99987113
# ramal 0.6525795
# munsareh 0.99832135
# baseet 0.9969309
# baseet 0.9241368
# kamel 0.996777
# madeed 0.7972379
# taweel 0.9884792
# rajaz 0.6535661
# rajaz 0.9772888
# saree 0.9992994
# kamel 0.9984029
# saree 0.9963104
# baseet 0.9963387
# ramal 0.4440568
# mutadarak 0.9325506
# saree 0.9472817
# saree 0.98659825
# saree 0.99909973
# wafer 0.9135822
# saree 0.98558676
# saree 0.8454512
# kamel 0.9998479
# taweel 0.5892517
# rajaz 0.99967575
# khafeef 0.9998313
# baseet 0.8713832
# khafeef 0.7450135
# taweel 0.9535897
# wafer 0.6013643
# kamel 0.8554177
# taweel 0.6247834
# khafeef 0.9999968
# rajaz 0.9997974
# ramal 0.998792
# ramal 0.99982005
# baseet 0.9959586
# saree 0.747962
# taweel 0.9910739
# munsareh 0.92504644
# mutakareb 0.577544
# mutakareb 0.96294934
# taweel 0.9297299
# saree 0.9443368
# khafeef 0.990436
# baseet 0.9833844
# ramal 0.9909586
# madeed 0.39918658
# kamel 0.99242413
# mujtath 0.9999287
# kamel 0.99647325
# khafeef 0.99969935
# ramal 0.9999943
# kamel 0.98977494
# rajaz 0.29199517
# kamel 0.77151304
# baseet 0.99696726
# saree 0.9966684
# munsareh 0.9954587
# wafer 0.98780835
# munsareh 0.9984744
# mujtath 0.9985862
# munsareh 0.9992667
# rajaz 0.7304482
# ramal 0.7197776
# ramal 0.9999918
# rajaz 0.9433995
# mutadarak 0.9122665
# baseet 0.9773121
# rajaz 0.30142766
# kamel 0.6354799
# wafer 0.9816336
# kamel 0.6845141
# ramal 0.9998299
# munsareh 0.9998286
# mutakareb 0.9714931
# taweel 0.9938046
# munsareh 0.60861135
# saree 0.99899143
# ramal 0.72370535
# kamel 0.39406338
# wafer 0.5860981
# khafeef 0.99999225
# taweel 0.9983114
# baseet 0.68376654
# mujtath 0.99985886
# rajaz 0.71627676
# mutakareb 0.99017674
# kamel 0.9994505
# taweel 0.9819156
# kamel 0.9996524
# munsareh 0.66750354
# mutadarak 0.4524511
# kamel 0.75635797
# saree 0.79017067
# kamel 0.51730245
# saree 0.9779679
# mutakareb 0.9886091
# mujtath 0.99994135
# madeed 0.77520686
# baseet 0.9828447
# kamel 0.49776456
# kamel 0.9689642
# saree 0.9918064
# mutakareb 0.99550784
# wafer 0.8925655
# munsareh 0.9982638
# rajaz 0.976844
# rajaz 0.98190296
# baseet 0.98900956
# mutakareb 0.5207486
# wafer 0.726168
# ramal 0.9998103
# rajaz 0.6082057
# baseet 0.59953296
# ramal 0.9993143
# baseet 0.9980171
# saree 0.97742885
# madeed 0.8659704
# khafeef 0.99910957
# taweel 0.99112904
# kamel 0.9993981
# saree 0.9983602
# kamel 0.8270667
# saree 0.9989802
# taweel 0.99519956
# khafeef 0.9996598
# wafer 0.9921904
# baseet 0.8669656
# wafer 0.9313604
# wafer 0.98261964
# taweel 0.87473726
# rajaz 0.99579155
# taweel 0.9999958
# mujtath 0.99989426
# saree 0.97384936
# baseet 0.961251
# wafer 0.9420047
# baseet 0.9986634
# kamel 0.7691356
# taweel 0.98612994
# wafer 0.998083
# kamel 0.9804238
# rajaz 0.96416706
# kamel 0.9993345
# munsareh 0.97140783
# mutakareb 0.8427042
# wafer 0.98996955
# rajaz 0.9648395
# saree 0.99469984
# kamel 0.7617876
# khafeef 0.9999901
# saree 0.52826124
# khafeef 0.62662995
# khafeef 0.9999982
# rajaz 0.88883245
# baseet 0.982297
# baseet 0.9987602
# wafer 0.7946075
# rajaz 0.9621009
# khafeef 0.99929416
# khafeef 0.9627053
# saree 0.8644521
# rajaz 0.99221367
# wafer 0.9802153
# baseet 0.9711492
# baseet 0.95815426
# khafeef 0.98259443
# khafeef 0.9997931
# taweel 0.99996054
# kamel 0.9999814
# khafeef 0.9999925
# wafer 0.99685186
# ramal 0.541774
# taweel 0.7459986
# mujtath 0.75850904
# baseet 0.99836224
# taweel 0.8895175
# ramal 0.9851001
# mutakareb 0.9738479
# mutakareb 0.47618473
# kamel 0.7047067
# munsareh 0.999724
# wafer 0.61607224
# saree 0.33264607
# ramal 0.99996877
# mutakareb 0.9374374
# baseet 0.98004866
# mutakareb 0.90941477
# kamel 0.9756629
# rajaz 0.9891567
# baseet 0.9565844
# ramal 0.99963427
# rajaz 0.9993412
# mutakareb 0.98846495
# kamel 0.49309933
# kamel 0.75517774
# khafeef 0.9568458
# ramal 0.92202437
# khafeef 0.7935745
# baseet 0.9814964
# hazaj 0.71534556
# mutakareb 0.48468456
# saree 0.852157
# baseet 0.99749315
# saree 0.66547465
# mutadarak 0.69978386
# taweel 0.9872824
# taweel 0.9693766
# kamel 0.99396175
# mutakareb 0.99513346
# saree 0.99370426
# khafeef 0.99968004
# taweel 0.948313
# khafeef 0.9982535
# saree 0.86455697
# baseet 0.97554827
# baseet 0.97566867
# khafeef 0.9999448
# khafeef 0.99908006
# wafer 0.6371126
# saree 0.51668566
# madeed 0.44536877
# kamel 0.99958664
# mujtath 0.9991967
# baseet 0.9935135
# khafeef 0.7840288
# taweel 0.5899881
# mutakareb 0.9999697
# khafeef 0.9998839
# ramal 0.9660265
# rajaz 0.8057854
# hazaj 0.36052012
# ramal 0.95050114
# wafer 0.81378436
# ramal 0.9997377
# saree 0.9747
# mutakareb 0.70131403
# saree 0.8274868
# saree 0.99950457
# ramal 0.99992394
# kamel 0.76957476
# mutakareb 0.7950906
# rajaz 0.8260532
# baseet 0.9190464
# munsareh 0.99987054
# wafer 0.98392856
# baseet 0.9998091
# ramal 0.99999666
# taweel 0.99944717
# hazaj 0.82203835
# khafeef 0.95461905
# kamel 0.7585664
# rajaz 0.9587351
# baseet 0.99943906
# kamel 0.991744
# baseet 0.9705691
# khafeef 0.9999764
# baseet 0.99558324
# baseet 0.9208651
# saree 0.99934393
# kamel 0.617719
# saree 0.99652606
# ramal 0.9999628
# wafer 0.78858614
# rajaz 0.97313863
# wafer 0.74129945
# khafeef 0.9600775
# khafeef 0.9999982
# taweel 0.9248294
# khafeef 0.99967647
# munsareh 0.9996044
# mutakareb 0.46277776
# khafeef 0.9996567
# saree 0.6428772
# munsareh 0.9697621
# kamel 0.93390465
# baseet 0.9787264
# rajaz 0.99739885
# baseet 0.9998915
# ramal 0.99998784
# khafeef 0.9999857
# rajaz 0.9438256
# kamel 0.8212849
# mutakareb 0.8143524
# khafeef 0.56370074
# taweel 0.9765044
# baseet 0.9960175
# munsareh 0.9998692
# mutakareb 0.99329257
# kamel 0.77497375
# munsareh 0.97533494
# khafeef 0.9999119
# wafer 0.93708116
# munsareh 0.95842445
# wafer 0.97631806
# taweel 0.99914753
# munsareh 0.8707855
# baseet 0.9989807
# taweel 0.91672945
# baseet 0.83743256
# baseet 0.9994512
# saree 0.5034283
# rajaz 0.90673745
# saree 0.9976369
# wafer 0.68064356
# baseet 0.9880086
# taweel 0.98479027
# rajaz 0.9992229
# saree 0.99091434
# baseet 0.998175
# khafeef 0.5831222
# mujtath 0.9999337
# ramal 0.9944834
# rajaz 0.35479245
# baseet 0.99708694
# mutakareb 0.9993643
# khafeef 0.9997272
# mujtath 0.77527744
# rajaz 0.96659285
# khafeef 0.7662295
# munsareh 0.9996612
# baseet 0.99799407
# rajaz 0.9290492
# khafeef 0.99999344
# mutakareb 0.97480756
# mutakareb 0.69429564
# rajaz 0.73643714
# taweel 0.99881554
# taweel 0.8471362
# khafeef 0.99992764
# taweel 0.9911731
# saree 0.99501425
# mutakareb 0.54712284
# ramal 0.99750215
# taweel 0.9987361
# saree 0.95869136
# saree 0.9995158
# munsareh 0.999288
# mutakareb 0.8800182
# wafer 0.37000987
# saree 0.54465675
# taweel 0.9582141
# saree 0.9958556
# khafeef 0.8772765
# kamel 0.9980421
# munsareh 0.8634345
# rajaz 0.32650352
# khafeef 0.98009104
# taweel 0.97375816
# saree 0.9932389
# mutakareb 0.92043924
# wafer 0.9867801
# saree 0.46259376
# ramal 0.72986776
# wafer 0.8969967
# baseet 0.9965205
# mutakareb 0.9983474
# saree 0.99914134
# taweel 0.48493886
# ramal 0.9582783
# khafeef 0.99991786
# kamel 0.9999043
# madeed 0.9902291
# saree 0.88940763
# mutakareb 0.99979514
# saree 0.43743098
# khafeef 0.74362755
# mutakareb 0.9839751
# rajaz 0.8994105
# kamel 0.995531
# wafer 0.95203424
# taweel 0.98918355
# rajaz 0.8416658
# rajaz 0.97012186
# kamel 0.99749386
# mutakareb 0.6759394
# rajaz 0.9833838
# baseet 0.9997596
# baseet 0.75409865
# ramal 0.7886393
# khafeef 0.96824807
# munsareh 0.7211476
# ramal 0.56019074
# khafeef 0.6473888
# rajaz 0.724276
# khafeef 0.9996455
# rajaz 0.87055176
# munsareh 0.9956222
# baseet 0.97804993
# baseet 0.99894124
# saree 0.99776185
# kamel 0.99830073
# wafer 0.97532564
# khafeef 0.9991898
# mutadarak 0.9942016
# ramal 0.9999883
# ramal 0.9997795
# ramal 0.94437283
# baseet 0.9972379
# ramal 0.97861594
# ramal 0.9997838
# saree 0.9932326
# rajaz 0.9935867
# rajaz 0.9229369
# mutakareb 0.9929811
# ramal 0.999915
# baseet 0.99047005
# saree 0.6824709
# mutakareb 0.99863595
# mutakareb 0.99961346
# kamel 0.6867712
# wafer 0.70422536
# khafeef 0.9999709
# khafeef 0.6402394
# baseet 0.9957767
# wafer 0.7122281
# taweel 0.9880227
# baseet 0.9330213
# ramal 0.99670106
# rajaz 0.999624
# ramal 0.9996762
# mutadarak 0.96619564
# kamel 0.9981219
# munsareh 0.99833316
# saree 0.99810934
# baseet 0.9809629
# ramal 0.99991393
# saree 0.19329965
# rajaz 0.95122653
# rajaz 0.99048
# khafeef 0.98359734
# khafeef 0.96718496
# khafeef 0.99986994
# khafeef 0.99995375
# mutakareb 0.95748246
# ramal 0.9976324
# munsareh 0.79858845
# saree 0.9969416
# saree 0.5295761
# ramal 0.9896903
# taweel 0.9940988
# taweel 0.9937044
# rajaz 0.9537937
# saree 0.9988255
# mujtath 0.999866
# ramal 0.99996006
# wafer 0.84745
# kamel 0.98113245
# mutakareb 0.99953306
# kamel 0.7257542
# mutadarak 0.6481042
# taweel 0.9946343
# wafer 0.8968619
# taweel 0.95744973
# ramal 0.28448677
# baseet 0.99915946
# baseet 0.939716
# munsareh 0.99349654
# saree 0.6565674
# mutakareb 0.9688889
# ramal 0.9594955
# kamel 0.98487586
# baseet 0.78740454
# saree 0.48925108
# kamel 0.99993896
# mutakareb 0.68552285
# khafeef 0.93410283
# taweel 0.98688716
# baseet 0.95682037
# baseet 0.95776284
# kamel 0.39666516
# wafer 0.99226576
# saree 0.9917229
# kamel 0.922703
# mutakareb 0.9981609
# saree 0.9756505
# hazaj 0.98567516
# baseet 0.8516918
# saree 0.960379
# mutakareb 0.98781455
# taweel 0.97775924
# ramal 0.9986523
# baseet 0.9989704
# mutakareb 0.94596654
# kamel 0.9998728
# rajaz 0.9660855
# baseet 0.52650476
# rajaz 0.65612245
# rajaz 0.5581508
# rajaz 0.99097604
# baseet 0.9996773
# taweel 0.826567
# kamel 0.9946196
# baseet 0.78452426
# munsareh 0.9996896
# wafer 0.78023535
# taweel 0.9742649
# madeed 0.4254345
# ramal 0.89346987
# baseet 0.98790365
# kamel 0.99969065
# ramal 0.9857691
# rajaz 0.95613986
# munsareh 0.99984753
# baseet 0.9905055
# khafeef 0.96320987
# madeed 0.8911342
# kamel 0.83045954
# rajaz 0.70827454
# wafer 0.6978856
# mujtath 0.9996171
# mujtath 0.9814347
# ramal 0.97945064
# mutakareb 0.96434283
# khafeef 0.82048416
# rajaz 0.9905199
# mujtath 0.925274
# mutakareb 0.94779444
# saree 0.9987556
# kamel 0.39554378
# rajaz 0.99988437
# ramal 0.998492
# wafer 0.97914404
# ramal 0.998473
# saree 0.7706038
# mutakareb 0.9043832
# khafeef 0.9793514
# saree 0.9948768
# baseet 0.981833
# baseet 0.9985551
# rajaz 0.5967225
# mutakareb 0.59905136
# ramal 0.9914137
# baseet 0.9964863
# khafeef 0.9995479
# mutakareb 0.9349182
# khafeef 0.99998164
# kamel 0.85216343
# khafeef 0.41370627
# wafer 0.8710783
# rajaz 0.9974407
# ramal 0.9999753
# kamel 0.9986564
# khafeef 0.9999652
# rajaz 0.9991215
# mutakareb 0.97002304
# baseet 0.99135274
# saree 0.77025086
# wafer 0.9916305
# khafeef 0.9999734
# taweel 0.84394497
# ramal 0.9983039
# taweel 0.8908204
# wafer 0.91725963
# kamel 0.64859277
# ramal 0.9484553
# kamel 0.6022134
# saree 0.99983025
# kamel 0.99995255
# mutakareb 0.9997279
# mutakareb 0.98715186
# saree 0.7163567
# mutakareb 0.87618005
# mujtath 0.9999913
# saree 0.37543067
# munsareh 0.98111504
# baseet 0.86730254
# khafeef 0.99956506
# baseet 0.9959124
# mutakareb 0.99162686
# rajaz 0.6115347
# baseet 0.9989008
# khafeef 0.6682953
# taweel 0.9997665
# ramal 0.9987962
# mutakareb 0.96631825
# khafeef 0.9140015
# taweel 0.79198974
# mutakareb 0.93878615
# khafeef 0.99995613
# saree 0.9081013
# wafer 0.80293936
# mutakareb 0.9588629
# taweel 0.9099582
# saree 0.99756706
# taweel 0.970747
# mujtath 0.9827451
# kamel 0.54675305
# wafer 0.9790918
# taweel 0.9994516
# kamel 0.9768664
# khafeef 0.9998747
# baseet 0.99111336
# ramal 0.9952354
# khafeef 0.99997807
# khafeef 0.9999529
# rajaz 0.48227143
# khafeef 0.9994716
# ramal 0.97652847
# rajaz 0.9999794
# ramal 0.4818486
# munsareh 0.95967525
# taweel 0.98331624
# rajaz 0.9114764
# baseet 0.9944476
# baseet 0.98821765
# khafeef 0.9999988
# wafer 0.968732
# kamel 0.998295
# baseet 0.99777824
# madeed 0.8564915
# saree 0.99964345
# mutakareb 0.9999378
# mutakareb 0.99934345
# rajaz 0.6978051
# khafeef 0.9999541
# munsareh 0.9971463
# taweel 0.9961528
# taweel 0.9949254
# khafeef 0.9999536
# khafeef 0.99999654
# rajaz 0.9257636
# saree 0.85162497
# mutakareb 0.9917311
# kamel 0.92617166
# kamel 0.9986902
# wafer 0.7049288
# munsareh 0.49398983
# taweel 0.9821361
# taweel 0.98795646
# khafeef 0.9999901
# rajaz 0.9970348
# rajaz 0.99996364
# khafeef 0.99998057
# khafeef 0.9995359
# saree 0.9995759
# baseet 0.99936396
# mutakareb 0.9866464
# kamel 0.99230826
# taweel 0.7184034
# mutakareb 0.69356
# saree 0.9978307
# kamel 0.9102179
# khafeef 0.9985519
# taweel 0.49047238
# taweel 0.9245416
# munsareh 0.9988207
# mutakareb 0.8596827
# munsareh 0.9982071
# ramal 0.99998724
# saree 0.9986174
# khafeef 0.9999945
# rajaz 0.86945593
# ramal 0.9994987
# baseet 0.99835724
# kamel 0.9849775
# taweel 0.9929414
# ramal 0.99993587
# taweel 0.9904937
# wafer 0.7942173
# kamel 0.97134
# wafer 0.999471
# saree 0.7338417
# wafer 0.49181977
# kamel 0.98531044
# wafer 0.8939254
# rajaz 0.9613187
# saree 0.8082674
# mutakareb 0.72048926
# taweel 0.9845328
# ramal 0.989884
# khafeef 0.98058265
# munsareh 0.9998423
# baseet 0.88409376
# kamel 0.99549943
# kamel 0.9739223
# mutakareb 0.8863888
# mutakareb 0.9999615
# khafeef 0.6007083
# ramal 0.9951107
# kamel 0.999938
# baseet 0.99487656
# wafer 0.9744703
# rajaz 0.9877164
# wafer 0.88741773
# baseet 0.9969512
# rajaz 0.88523984
# rajaz 0.9994399
# kamel 0.99950445
# wafer 0.9989768
# ramal 0.99313146
# ramal 0.9999888
# baseet 0.9617151
# taweel 0.9924049
# khafeef 0.9995716
# taweel 0.9988034
# wafer 0.6995268
# mutakareb 0.46945003
# munsareh 0.7559462
# munsareh 0.99954695
# rajaz 0.999951
# rajaz 0.9993498
# baseet 0.9970511
# kamel 0.99529415
# munsareh 0.9890265
# mujtath 0.99952006
# khafeef 0.9998907
# rajaz 0.97501737
# mutakareb 0.99616194
# wafer 0.9083039
# ramal 0.99919826
# taweel 0.9993599
# wafer 0.5075579
# ramal 0.79027784
# baseet 0.94967175
# munsareh 0.9992403
# baseet 0.9821187
# wafer 0.5641857
# mutakareb 0.6399222
# wafer 0.9742361
# mutakareb 0.95841384
# wafer 0.62746704
# saree 0.834197
# wafer 0.9822479
# ramal 0.99982446
# khafeef 0.996926
# taweel 0.8885468
# khafeef 0.99948347
# rajaz 0.9998789
# rajaz 0.9983809
# ramal 0.99979204
# ramal 0.58152884
# saree 0.95739293
# mujtath 0.90270174
# baseet 0.9785679
# baseet 0.99704546
# ramal 0.9416486
# madeed 0.8302008
# rajaz 0.45279545
# baseet 0.9651773
# rajaz 0.9968322
# saree 0.99467224
# khafeef 0.9999857
# khafeef 0.9999906
# kamel 0.9999702
# rajaz 0.85574174
# mutakareb 0.47633418
# mutakareb 0.74698627
# khafeef 0.99465334
# taweel 0.71942115
# saree 0.8776858
# rajaz 0.9219131
# baseet 0.9994943
# kamel 0.98650175
# khafeef 0.99990964
# saree 0.9136581
# mutakareb 0.9897064
# ramal 0.9999516
# rajaz 0.99632084
# khafeef 0.9998851
# wafer 0.7913284
# baseet 0.9662872
# rajaz 0.5413646
# rajaz 0.97076946
# ramal 0.9999331
# mujtath 0.4207596
# mutakareb 0.51066005
# mutakareb 0.98210114
# saree 0.9992518
# baseet 0.9983046
# rajaz 0.9734807
# mutakareb 0.77350354
# rajaz 0.97315717
# rajaz 0.49854323
# rajaz 0.8291983
# munsareh 0.9996817
# saree 0.9525815
# mutakareb 0.9822037
# munsareh 0.99925154
# khafeef 0.99994624
# khafeef 0.99936634
# rajaz 0.9998592
# taweel 0.99596417
# wafer 0.99642545
# saree 0.9987953
# kamel 0.9975085
# saree 0.6392458
# rajaz 0.9999788
# taweel 0.72579455
# wafer 0.9990319
# kamel 0.9875187
# khafeef 0.9793591
# mujtath 0.9999864
# wafer 0.9483067
# munsareh 0.9645189
# mutakareb 0.62671983
# madeed 0.51199967
# khafeef 0.60670966
# rajaz 0.27880684
# ramal 0.9995161
# munsareh 0.99992645
# kamel 0.54877204
# kamel 0.9896393
# wafer 0.5114589
# mutakareb 0.53319657
# wafer 0.9920414
# saree 0.33477932
# wafer 0.9650967
# rajaz 0.9990907
# ramal 0.97300684
# rajaz 0.95913017
# mutakareb 0.9871588
# baseet 0.99095714
# taweel 0.9539009
# munsareh 0.99970067
# khafeef 0.998587
# khafeef 0.9999683
# rajaz 0.77252483
# mutakareb 0.9941902
# kamel 0.752329
# kamel 0.99875474
# kamel 0.9998185
# baseet 0.97608817
# munsareh 0.94940734
# wafer 0.71165526
# khafeef 0.9699435
# wafer 0.9976084
# khafeef 0.9998654
# rajaz 0.93060106
# munsareh 0.999749
# wafer 0.96184844
# kamel 0.9999019
# baseet 0.9572166
# ramal 0.71125996
# ramal 0.991651
# saree 0.9593751
# ramal 0.99996483
# khafeef 0.87554616
# ramal 0.97522163
# saree 0.9673227
# khafeef 0.9997174
# taweel 0.8295378
# mutakareb 0.9967618
# saree 0.85458577
# taweel 0.98817796
# khafeef 0.9999974
# baseet 0.9903003
# kamel 0.99908674
# munsareh 0.99506336
# saree 0.9987709
# taweel 0.99958783
# wafer 0.9669822
# ramal 0.9103538
# saree 0.996847
# munsareh 0.99988186
# mutakareb 0.99640983
# ramal 0.7781142
# rajaz 0.9994814
# mutakareb 0.88127023
# munsareh 0.97686654
# taweel 0.64280915
# ramal 0.9999976
# mutakareb 0.9965173
# rajaz 0.99465346
# khafeef 0.9999244
# wafer 0.85681343
# baseet 0.67197883
# wafer 0.92409223
# kamel 0.9643102
# kamel 0.74569345
# saree 0.9978683
# mutakareb 0.83449155
# rajaz 0.9979698
# saree 0.9988166
# baseet 0.9980513
# baseet 0.9974038
# taweel 0.9576045
# wafer 0.5477175
# saree 0.9568345
# wafer 0.91969097
# khafeef 0.90865576
# kamel 0.99987805
# kamel 0.56740713
# taweel 0.60878515
# saree 0.9983224
# rajaz 0.89791965
# wafer 0.974398
# taweel 0.9939792
# saree 0.9976301
# rajaz 0.90903187
# saree 0.9956027
# khafeef 0.9999434
# munsareh 0.9933502
# taweel 0.99647444
# taweel 0.9081626
# khafeef 0.9999975
# baseet 0.9996792
# baseet 0.9943303
# taweel 0.9999825
# 0

# %%
test_data_df =  pd.DataFrame(test_data_dictionary.items(), columns=['id', 'labels'])
test_data_df.head()
# Out:
#    id  labels
# 0   0       8
# 1   1       2
# 2   2       2
# 3   3      10
# 4   4      11

# %% [markdown]
# ### Saving Final Predictions to CSV File

# %%
test_data_df.to_csv('MAAN_Final.csv', header=True, index=False)
